# %%
# %pylab inline
import glob
import os
import seaborn as sns
sns.set()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/dansandiford/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
topdir = '/Users/dansandiford/Documents/programming/earthsci_code/python/vueesc/output_stash/results'

# %% [markdown]
# ## A0 - B0

# %%
A0_1  = np.genfromtxt(os.path.join(topdir,  "A/0/1/results_modelA_0_1.dat"), skip_header=0, skip_footer=1)
A0_4  = np.genfromtxt(os.path.join(topdir,  "A/0/4/results_modelA_0_4.dat"), skip_header=0, skip_footer=1)
A0_7  = np.genfromtxt(os.path.join(topdir,  "A/0/7/results_modelA_0_7.dat"), skip_header=0, skip_footer=1)
A0_10  = np.genfromtxt(os.path.join(topdir,  "A/0/10/results_modelA_0_10.dat"), skip_header=0, skip_footer=1)


B0_1  = np.genfromtxt(os.path.join(topdir,  "B/0/1/results_modelB_0_1.dat"), skip_header=0, skip_footer=1)
B0_4  = np.genfromtxt(os.path.join(topdir,  "B/0/4/results_modelB_0_4.dat"), skip_header=0, skip_footer=1)
B0_7  = np.genfromtxt(os.path.join(topdir,  "B/0/7/results_modelB_0_7.dat"), skip_header=0, skip_footer=1)
B0_10  = np.genfromtxt(os.path.join(topdir,  "B/0/10/results_modelB_0_10.dat"), skip_header=0, skip_footer=1)

# %%
B0_7.shape
# Out:
# (596, 16)

# %%
col = 2
ax1 = plt.subplot(111)

#ax1.set_xlim([0.0, 0.01])
#ax1.set_ylim([0., 4.])



plt.plot(A0_1[:,0], -1*A0_1[:,col]/2., c='r',label="A0_1")
plt.plot(A0_4[:,0], -1*A0_4[:,col]/2., c='k',label="A0_4")
plt.plot(A0_7[:,0], -1*A0_7[:,col]/2., c='g',label="A0_7")
plt.plot(A0_10[:,0], -1*A0_10[:,col]/2., c='b',label="A0_10")


plt.plot(B0_1[:,0], -1*B0_1[:,col], 'r--',label="B0_1")
plt.plot(B0_4[:,0], -1*B0_4[:,col], 'k--',label="B0_4")
plt.plot(B0_7[:,0], -1*B0_7[:,col], 'g--',label="B0_7")
plt.plot(B0_10[:,0], -1*B0_10[:,col], 'b--',label="B0_10")

plt.xlabel("dimensionless t")
plt.ylabel("Surface Nusselt value")

plt.legend()

plt.savefig('A0Nusselt.png')

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A0_4
B0 = B0_4

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A0")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B0")

plt.tight_layout()
plt.legend()
#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A0")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B0")
ax2.set_xlim([0.0, 0.15])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A0")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax3.set_title('visc. diss. - lith')


#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], -1*A0[:,2]/2., 'k-',label="A0")
ax4.plot(B0[:,0], -1*B0[:,2], 'r-',label="B0")
#ax2.set_xlim([0.0, 0.15])
ax4.set_title('Nusselt base')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], -1*A0[:,3]/2., 'k-',label="A0")
ax5.plot(B0[:,0], -1*B0[:,3], 'r-',label="B0")
#ax3.set_xlim([0.0, 0.15])
ax5.set_title('Nusselt surf.')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A0")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B0")
#ax5.set_xlim([0.0, 0.15])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A0")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A0")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B0")
ax8.set_xlim([0.0, 0.15])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A0")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B0")
#ax8.set_xlim([0.0, 0.15])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A0")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B0")
#ax4.set_xlim([0.0, 0.15])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A0")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A0")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax12.set_title('Max stress')


plt.legend()

plt.tight_layout()
fig = plt.gcf()
fig.savefig("A0_1metrics.png")

# %%
A0[:,14].max()
# Out:
# 11118.8876669

# %% [markdown]
# ## A1 - B1

# %%
A1_1  = np.genfromtxt(os.path.join(topdir,  "A/1/1/results_modelA_1_1.dat"), skip_header=0, skip_footer=1)
A1_4  = np.genfromtxt(os.path.join(topdir,  "A/1/4/results_modelA_1_4.dat"), skip_header=0, skip_footer=1)
A1_7  = np.genfromtxt(os.path.join(topdir,  "A/1/7/results_modelA_1_7.dat"), skip_header=0, skip_footer=1)
A1_10  = np.genfromtxt(os.path.join(topdir,  "A/1/10/results_modelA_1_10.dat"), skip_header=0, skip_footer=1)


B1_1  = np.genfromtxt(os.path.join(topdir,  "B/1/1/results_modelB_1_1.dat"), skip_header=0, skip_footer=1)
B1_4  = np.genfromtxt(os.path.join(topdir,  "B/1/4/results_modelB_1_4.dat"), skip_header=0, skip_footer=1)
B1_7  = np.genfromtxt(os.path.join(topdir,  "B/1/7/results_modelB_1_7.dat"), skip_header=0, skip_footer=1)
B1_10  = np.genfromtxt(os.path.join(topdir,  "B/1/10/results_modelB_1_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

#ax1.set_xlim([0.0, 0.17])
#ax1.set_ylim([0.499, 0.503])

plt.plot(A1_1[:,0], -1*A1_1[:,col]/2., c='r',label="A1_1")
plt.plot(A1_4[:,0], -1*A1_4[:,col]/2., c='k',label="A1_4")
plt.plot(A1_7[:,0], -1*A1_7[:,col]/2., c='g',label="A1_7")
plt.plot(A1_10[:,0], -1*A1_10[:,col]/2., c='b',label="A1_10")


plt.plot(B1_1[:,0], -1*B1_1[:,col], 'r--',label="B1_1")
plt.plot(B1_4[:,0], -1*B1_4[:,col], 'k--',label="B1_4")
plt.plot(B1_7[:,0], -1*B1_7[:,col], 'g--',label="B1_7")
plt.plot(B1_10[:,0], -1*B1_10[:,col], 'b--',label="B1_10")

plt.xlabel("dimensionless t")
plt.ylabel("Surface Nusselt value")

plt.legend()

plt.savefig('A1Nusselt.png')

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A1_7
B0 = B1_7

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A1")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B1")

plt.tight_layout()
plt.legend()
#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A0")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B0")
ax2.set_xlim([0.0, 0.15])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A1")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B1")
#ax9.set_xlim([0.0, 0.15])
ax3.set_title('visc. diss. - lith')


#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], -1*A0[:,2]/2., 'k-',label="A1")
ax4.plot(B0[:,0], -1*B0[:,2], 'r-',label="B1")
#ax2.set_xlim([0.0, 0.15])
ax4.set_title('Nusselt base')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], -1*A0[:,3]/2., 'k-',label="A1")
ax5.plot(B0[:,0], -1*B0[:,3], 'r-',label="B1")
#ax3.set_xlim([0.0, 0.15])
ax5.set_title('Nusselt surf.')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A1")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B1")
#ax5.set_xlim([0.0, 0.15])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A1")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B1")
#ax9.set_xlim([0.0, 0.15])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A1")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B1")
ax8.set_xlim([0.0, 0.15])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A1")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B1")
#ax8.set_xlim([0.0, 0.15])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A1")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B1")
#ax4.set_xlim([0.0, 0.15])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A1")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B1")
#ax9.set_xlim([0.0, 0.15])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A1")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B1")
#ax9.set_xlim([0.0, 0.15])
ax12.set_title('Max stress')



plt.legend()

plt.tight_layout()
fig = plt.gcf()

fig.savefig("A1_1metrics.png")

# %% [markdown]
# ## A2 - B2

# %%
B2_1  = np.genfromtxt(os.path.join(topdir,  "B/2/1/results_modelB_2_1.dat"), skip_header=0, skip_footer=1)
B2_4  = np.genfromtxt(os.path.join(topdir,  "B/2/4/results_modelB_2_4.dat"), skip_header=0, skip_footer=1)
B2_7  = np.genfromtxt(os.path.join(topdir,  "B/2/7/results_modelB_2_7.dat"), skip_header=0, skip_footer=1)
B2_10  = np.genfromtxt(os.path.join(topdir,  "B/2/10/results_modelB_2_10.dat"), skip_header=0, skip_footer=1)

A2_1  = np.genfromtxt(os.path.join(topdir,  "A/2/1/results_modelA_2_1.dat"), skip_header=0, skip_footer=1)
A2_4  = np.genfromtxt(os.path.join(topdir,  "A/2/4/results_modelA_2_4.dat"), skip_header=0, skip_footer=1)
A2_7  = np.genfromtxt(os.path.join(topdir,  "A/2/7/results_modelA_2_7.dat"), skip_header=0, skip_footer=1)
A2_10  = np.genfromtxt(os.path.join(topdir,  "A/2/10/results_modelA_2_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.04])
#ax1.set_ylim([0.499, 0.503])



plt.plot(A2_1[:,0], -1*A2_1[:,col]/2., c='r',label="A2_1")
plt.plot(A2_4[:,0], -1*A2_4[:,col]/2., c='k',label="A2_4")
plt.plot(A2_7[:,0], -1*A2_7[:,col]/2, c='g',label="A2_7")
plt.plot(A2_10[:,0], -1*A2_10[:,col]/2., c='b',label="A2_10")


plt.plot(B2_1[:,0], -1*B2_1[:,col], 'r--',label="B2_1")
plt.plot(B2_4[:,0], -1*B2_4[:,col], 'k--',label="B2_4")
plt.plot(B2_7[:,0], -1*B2_7[:,col], 'g--',label="B2_7")
plt.plot(B2_10[:,0], -1*B2_10[:,col], 'b--',label="B2_10")



plt.xlabel("dimensionless t")
plt.ylabel("Surface Nusselt value")

plt.legend()

plt.savefig('A2Nusselt.png')

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A2_10
B0 = B2_10

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A2")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B2")

plt.tight_layout()
plt.legend()
#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A2")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B2")
#ax2.set_xlim([0.0, 0.15])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A2")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B2")
#ax9.set_xlim([0.0, 0.15])
ax3.set_title('visc. diss. - lith')



#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], -1*A0[:,2]/2., 'k-',label="A2")
ax4.plot(B0[:,0], -1*B0[:,2], 'r-',label="B2")
#ax2.set_xlim([0.0, 0.15])
ax4.set_title('Nusselt base')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], -1*A0[:,3]/2., 'k-',label="A2")
ax5.plot(B0[:,0], -1*B0[:,3], 'r-',label="B2")
#ax3.set_xlim([0.0, 0.15])
ax5.set_title('Nusselt surf.')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A2")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B2")
#ax5.set_xlim([0.0, 0.15])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A2")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B2")
#ax9.set_xlim([0.0, 0.15])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A2")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B2")
#ax8.set_xlim([0.0, 0.15])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A2")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B2")
#ax8.set_xlim([0.0, 0.15])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A2")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B2")
#ax4.set_xlim([0.0, 0.15])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A2")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B2")
#ax9.set_xlim([0.0, 0.15])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A2")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B2")
#ax9.set_xlim([0.0, 0.15])
ax12.set_title('Max stress')

plt.legend()

plt.tight_layout()
fig = plt.gcf()

fig.savefig("A2_1metrics.png")

# %%
B3_1  = np.genfromtxt(os.path.join(topdir,  "B/3/1/results_modelB_3_1.dat"), skip_header=0, skip_footer=1)
B3_4  = np.genfromtxt(os.path.join(topdir,  "B/3/4/results_modelB_3_4.dat"), skip_header=0, skip_footer=1)
B3_7  = np.genfromtxt(os.path.join(topdir,  "B/3/7/results_modelB_3_7.dat"), skip_header=0, skip_footer=1)
B3_10  = np.genfromtxt(os.path.join(topdir,  "B/3/10/results_modelB_3_10.dat"), skip_header=0, skip_footer=1)

A3_1  = np.genfromtxt(os.path.join(topdir,  "A/3/1/results_modelA_3_1.dat"), skip_header=0, skip_footer=1)
A3_4  = np.genfromtxt(os.path.join(topdir,  "A/3/4/results_modelA_3_4.dat"), skip_header=0, skip_footer=1)
A3_7  = np.genfromtxt(os.path.join(topdir,  "A/3/7/results_modelA_3_7.dat"), skip_header=0, skip_footer=1)
A3_10  = np.genfromtxt(os.path.join(topdir,  "A/3/10/results_modelA_3_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.004])
#ax1.set_ylim([0.499, 0.503])

plt.plot(A3_1[:,0], -1*A3_1[:,col]/2., c='r',label="A3_1")
plt.plot(A3_4[:,0], -1*A3_4[:,col]/2., c='k',label="A3_4")
plt.plot(A3_7[:,0], -1*A3_7[:,col]/2., c='g',label="A3_7")
plt.plot(A3_10[:,0], -1*A3_10[:,col]/2., c='b',label="A3_10")


plt.plot(B3_1[:,0], -1*B3_1[:,col], 'r--',label="B3_1")
plt.plot(B3_4[:,0], -1*B3_4[:,col], 'k--',label="B3_4")
plt.plot(B3_7[:,0], -1*B3_7[:,col], 'g--',label="B3_7")
plt.plot(B3_10[:,0], -1*B3_10[:,col], 'b--',label="B3_10")


plt.xlabel("dimensionless t")
plt.ylabel("Surface Nusselt value")

plt.legend()

plt.savefig('A3Nusselt.png')

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A3_10
B0 = B3_10

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A3")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B3")
plt.legend()
plt.tight_layout()

#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A3")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B3")
ax2.set_xlim([0.0, 0.002])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A3")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B3")
ax3.set_xlim([0.0, 0.002])
ax3.set_title('visc. diss. - lith')


#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], -1*A0[:,2]/2., 'k-',label="A3")
ax4.plot(B0[:,0], -1*B0[:,2], 'r-',label="B3")
ax4.set_xlim([0.0, 0.002])
ax4.set_title('Nusselt base')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], -1*A0[:,3]/2., 'k-',label="A3")
ax5.plot(B0[:,0], -1*B0[:,3], 'r-',label="B3")
ax5.set_xlim([0.0, 0.002])
ax5.set_title('Nusselt surf.')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A3")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B3")
ax6.set_xlim([0.0, 0.002])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A3")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B3")
ax7.set_xlim([0.0, 0.002])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A3")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B3")
ax8.set_xlim([0.0, 0.002])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A3")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B3")
ax9.set_xlim([0.0, 0.002])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A3")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B3")
ax10.set_xlim([0.0, 0.002])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A3")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B3")
ax11.set_xlim([0.0, 0.002])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A3")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B3")
ax9.set_xlim([0.0, 0.002])
ax12.set_title('Max stress')



plt.tight_layout()
fig = plt.gcf()

fig.savefig("A3_1metrics.png")

# %%
#B3_1  = np.genfromtxt(os.path.join(topdir,  "B/3/1/results_modelB_3_1.dat"), skip_header=0, skip_footer=1)
#B3_4  = np.genfromtxt(os.path.join(topdir,  "B/3/4/results_modelB_3_4.dat"), skip_header=0, skip_footer=1)
#B3_7  = np.genfromtxt(os.path.join(topdir,  "B/3/7/results_modelB_3_7.dat"), skip_header=0, skip_footer=1)
#B3_10  = np.genfromtxt(os.path.join(topdir,  "B/3/10/results_modelB_3_10.dat"), skip_header=0, skip_footer=1)

A5_1  = np.genfromtxt(os.path.join(topdir,  "A/5/1/results_modelA_5_1.dat"), skip_header=0, skip_footer=1)
A5_4  = np.genfromtxt(os.path.join(topdir,  "A/5/4/results_modelA_5_4.dat"), skip_header=0, skip_footer=1)
A5_7  = np.genfromtxt(os.path.join(topdir,  "A/5/7/results_modelA_5_7.dat"), skip_header=0, skip_footer=1)
A5_10  = np.genfromtxt(os.path.join(topdir,  "A/5/10/results_modelA_5_10.dat"), skip_header=0, skip_footer=1)
A5_20  = np.genfromtxt(os.path.join(topdir,  "A/5/20/results_modelA_5_20.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

#ax1.set_xlim([0.0, 0.004])
#ax1.set_ylim([0.499, 0.503])

plt.plot(A5_1[:,0], -1*A5_1[:,col]/2., c='r',label="A5_1")
plt.plot(A5_4[:,0], -1*A5_4[:,col]/2., c='k',label="A5_4")
plt.plot(A5_7[:,0], -1*A5_7[:,col]/2., c='g',label="A5_7")
plt.plot(A5_10[:,0], -1*A5_10[:,col]/2., c='b',label="A5_10")
plt.plot(A5_20[:,0], -1*A5_20[:,col]/2., c='y',label="A5_20")



#plt.plot(B3_1[:,0], -1*B3_1[:,col], 'r--',label="B3_1")
#plt.plot(B3_4[:,0], -1*B3_4[:,col], 'k--',label="B3_4")
#plt.plot(B3_7[:,0], -1*B3_7[:,col], 'g--',label="B3_7")
#plt.plot(B3_10[:,0], -1*B3_10[:,col], 'b--',label="B3_10")


plt.xlabel("dimensionless t")
plt.ylabel("Surface Nusselt value")

plt.legend()

plt.savefig('A3Nusselt.png')
