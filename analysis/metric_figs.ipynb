# %%
# %pylab inline
import glob
import os
import seaborn as sns
sns.set()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
topdir = "/Users/dansandiford/Documents/model_local_copy/underworld/vueesc/"
workdir = '/Users/dansandiford/Documents/programming/earthsci_code/python/vueesc'

# %% [markdown]
# ## A0 - B0

# %%
A0_1  = np.genfromtxt(os.path.join(topdir,  "results/A/0/1/results_modelA_0_1.dat"), skip_header=0, skip_footer=1)
A0_4  = np.genfromtxt(os.path.join(topdir,  "results/A/0/4/results_modelA_0_4.dat"), skip_header=0, skip_footer=1)
A0_7  = np.genfromtxt(os.path.join(topdir,  "results/A/0/7/results_modelA_0_7.dat"), skip_header=0, skip_footer=1)
A0_10  = np.genfromtxt(os.path.join(topdir,  "results/A/0/10/results_modelA_0_10.dat"), skip_header=0, skip_footer=1)


B0_1  = np.genfromtxt(os.path.join(topdir,  "results/B/0/1/results_modelB_0_1.dat"), skip_header=0, skip_footer=1)
B0_4  = np.genfromtxt(os.path.join(topdir,  "results/B/0/4/results_modelB_0_4.dat"), skip_header=0, skip_footer=1)
B0_7  = np.genfromtxt(os.path.join(topdir,  "results/B/0/7/results_modelB_0_7.dat"), skip_header=0, skip_footer=1)
B0_10  = np.genfromtxt(os.path.join(topdir,  "results/B/0/10/results_modelB_0_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.17])
#ax1.set_ylim([0.499, 0.503])



plt.plot(A0_1[:,0], -1*A0_1[:,col], c='r',label="A0_1")
plt.plot(A0_4[:,0], -1*A0_4[:,col], c='k',label="A0_4")
plt.plot(A0_7[:,0], -1*A0_7[:,col], c='g',label="A0_7")
plt.plot(A0_10[:,0], -1*A0_10[:,col], c='b',label="A0_10")


plt.plot(B0_1[:,0], -1*B0_1[:,col], 'r--',label="B0_1")
plt.plot(B0_4[:,0], -1*B0_4[:,col], 'k--',label="B0_4")
plt.plot(B0_7[:,0], -1*B0_7[:,col], 'g--',label="B0_7")
plt.plot(B0_10[:,0], -1*B0_10[:,col], 'b--',label="B0_10")



plt.legend()

plt.savefig('Nusselt.png')

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A0_1
B0 = B0_1

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A0")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B0")

plt.tight_layout()

#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A0")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B0")
ax2.set_xlim([0.0, 0.15])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A0")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax3.set_title('visc. diss. - lith')





#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], A0[:,2], 'k-',label="A0")
ax4.plot(B0[:,0], B0[:,2], 'r-',label="B0")
#ax2.set_xlim([0.0, 0.15])
ax4.set_title('Nusselt 0')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], A0[:,3], 'k-',label="A0")
ax5.plot(B0[:,0], B0[:,3], 'r-',label="B0")
#ax3.set_xlim([0.0, 0.15])
ax5.set_title('Nusselt 1')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A0")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B0")
#ax5.set_xlim([0.0, 0.15])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A0")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A0")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B0")
ax8.set_xlim([0.0, 0.15])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A0")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B0")
#ax8.set_xlim([0.0, 0.15])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A0")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B0")
#ax4.set_xlim([0.0, 0.15])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A0")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A0")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax12.set_title('Max stress')



plt.legend()

plt.tight_layout()
fig = plt.gcf()
fig.savefig("A0_1metrics.png")

# %%
A0[:,14].max()
# Out:
# 496.975899459

# %%
col = 10
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.17])
#ax1.set_ylim([0.499, 0.503]

plt.plot(A0_1[:,0], A0_1[:,col], c='r',label="A0_1")
#plt.plot(B0_10[:,0], B0_10[:,col], 'b--',label="B0_10")



plt.legend(loc=4)

# %% [markdown]
# ## A1 - B1

# %%
A1_1  = np.genfromtxt(os.path.join(topdir,  "results/A/1/1/results_modelA_1_1.dat"), skip_header=0, skip_footer=1)
A1_4  = np.genfromtxt(os.path.join(topdir,  "results/A/1/4/results_modelA_1_4.dat"), skip_header=0, skip_footer=1)
A1_7  = np.genfromtxt(os.path.join(topdir,  "results/A/1/7/results_modelA_1_7.dat"), skip_header=0, skip_footer=1)
A1_10  = np.genfromtxt(os.path.join(topdir,  "results/A/1/10/results_modelA_1_10.dat"), skip_header=0, skip_footer=1)


B1_1  = np.genfromtxt(os.path.join(topdir,  "results/B/1/1/results_modelB_1_1.dat"), skip_header=0, skip_footer=1)
B1_4  = np.genfromtxt(os.path.join(topdir,  "results/B/1/4/results_modelB_1_4.dat"), skip_header=0, skip_footer=1)
B1_7  = np.genfromtxt(os.path.join(topdir,  "results/B/1/7/results_modelB_1_7.dat"), skip_header=0, skip_footer=1)
B1_10  = np.genfromtxt(os.path.join(topdir,  "results/B/1/10/results_modelB_1_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 3
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.17])
#ax1.set_ylim([0.499, 0.503])



plt.plot(A1_1[:,0], -1*A1_1[:,col], c='r',label="A1_1")
plt.plot(A1_4[:,0], -1*A1_4[:,col], c='k',label="A1_4")
plt.plot(A1_7[:,0], -1*A1_7[:,col], c='g',label="A1_7")
plt.plot(A1_10[:,0], -1*A1_10[:,col], c='b',label="A1_10")


plt.plot(B1_1[:,0], -1*B1_1[:,col], 'r--',label="B1_1")
plt.plot(B1_4[:,0], -1*B1_4[:,col], 'k--',label="B1_4")
plt.plot(B1_7[:,0], -1*B1_7[:,col], 'g--',label="B1_7")
plt.plot(B1_10[:,0], -1*B1_10[:,col], 'b--',label="B1_10")



plt.legend()

# %%
fig = plt.figure(figsize=(10, 10))

A0 = A1_1
B0 = B1_1

#Viscous diss
ax1 = fig.add_subplot(4,3,1)
ax1.plot(A0[:,0], A0[:,1]/(2*44668.35), 'k-',label="A0")
ax1.plot(B0[:,0], B0[:,1]/(2*44668.35), 'r-',label="B0")

plt.tight_layout()

#ax1.set_xlim([0.0, 0.15])
ax1.set_title('viscous dissipation')

ax2 = fig.add_subplot(4,3,2)
ax2.plot(A0[:,0], A0[:,8]/2, 'k-',label="A0")
ax2.plot(B0[:,0], B0[:,8], 'r-',label="B0")
ax2.set_xlim([0.0, 0.15])
ax2.set_title('Grav. work')

ax3 = fig.add_subplot(4,3,3)
ax3.plot(A0[:,0], A0[:,12]/(2*44668.35), 'k-',label="A0")
ax3.plot(B0[:,0], B0[:,12]/(2*44668.35), 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax3.set_title('visc. diss. - lith')





#Nu0
ax4 = fig.add_subplot(4,3,4)
ax4.plot(A0[:,0], A0[:,2], 'k-',label="A0")
ax4.plot(B0[:,0], B0[:,2], 'r-',label="B0")
#ax2.set_xlim([0.0, 0.15])
ax4.set_title('Nusselt 0')

ax5 = fig.add_subplot(4,3,5)
ax5.plot(A0[:,0], A0[:,3], 'k-',label="A0")
ax5.plot(B0[:,0], B0[:,3], 'r-',label="B0")
#ax3.set_xlim([0.0, 0.15])
ax5.set_title('Nusselt 1')


ax6 = fig.add_subplot(4,3,6)
ax6.plot(A0[:,0], A0[:,5], 'k-',label="A0")
ax6.plot(B0[:,0], B0[:,5], 'r-',label="B0")
#ax5.set_xlim([0.0, 0.15])
ax6.set_title('RMS vel.')

#This Metric is broken for Mesh, (probably working for particles)
ax7 = fig.add_subplot(4,3,7)
ax7.plot(A0[:,0], A0[:,7], 'k-',label="A0")
ax7.plot(B0[:,0], B0[:,7], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax7.set_title('Max. vx surface')


#This Metric is broken for particles
#ax6 = fig.add_subplot(336)
#ax6.plot(comb[:,0], comb[:,6], 'k-',label="Particle metric")
#ax6.plot(comb[:,0], comb[:,15], 'r--',label="Mesh metric")
#ax6.plot(orig[:,0], orig[:,6], 'b--',label="Tosi model")
#ax6.set_title('RMS vel. surface')


ax8 = fig.add_subplot(4,3,8)
ax8.plot(A0[:,0], A0[:,9], 'k-',label="A0")
ax8.plot(B0[:,0], B0[:,9], 'r-',label="B0")
ax8.set_xlim([0.0, 0.15])
ax8.set_title('Max. Visc.')

ax9 = fig.add_subplot(4,3,9)
ax9.plot(A0[:,0], A0[:,10], 'k-',label="A0")
ax9.plot(B0[:,0], B0[:,10], 'r-',label="B0")
#ax8.set_xlim([0.0, 0.15])
ax9.set_title('Min. Visc.')


ax10 = fig.add_subplot(4,3,10)
ax10.plot(A0[:,0], A0[:,4], 'k-',label="A0")
ax10.plot(B0[:,0], B0[:,4], 'r-',label="B0")
#ax4.set_xlim([0.0, 0.15])
ax10.set_title('Avg. temp')


ax11 = fig.add_subplot(4,3,11)
ax11.plot(A0[:,0], A0[:,13], 'k-',label="A0")
ax11.plot(B0[:,0], B0[:,13], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax11.set_title('avg. stress')

ax12 = fig.add_subplot(4,3,12)
ax12.plot(A0[:,0], A0[:,14], 'k-',label="A0")
ax12.plot(B0[:,0], B0[:,14], 'r-',label="B0")
#ax9.set_xlim([0.0, 0.15])
ax12.set_title('Max stress')



plt.legend()

plt.tight_layout()
fig = plt.gcf()

# %% [markdown]
# ## A2 - B2

# %%
B2_1  = np.genfromtxt(os.path.join(topdir,  "results/B/2/1/results_modelB_2_1.dat"), skip_header=0, skip_footer=1)
B2_4  = np.genfromtxt(os.path.join(topdir,  "results/B/2/4/results_modelB_2_4.dat"), skip_header=0, skip_footer=1)
B2_7  = np.genfromtxt(os.path.join(topdir,  "results/B/2/7/results_modelB_2_7.dat"), skip_header=0, skip_footer=1)
B2_10  = np.genfromtxt(os.path.join(topdir,  "results/B/2/10/results_modelB_2_10.dat"), skip_header=0, skip_footer=1)

A2_10  = np.genfromtxt(os.path.join(topdir,  "results/A/2/10/results_modelA_2_10.dat"), skip_header=0, skip_footer=1)

# %%
col = 4
ax1 = plt.subplot(111)

ax1.set_xlim([0.0, 0.02])
#ax1.set_ylim([0.499, 0.503])



#plt.plot(A0_1[:,0], -1*A0_1[:,col], c='r',label="A0_1")
#plt.plot(A0_4[:,0], -1*A0_4[:,col], c='k',label="A0_4")
#plt.plot(A0_7[:,0], -1*A0_7[:,col], c='g',label="A0_7")
plt.plot(A2_10[:,0], -1*A2_10[:,col], c='b',label="A2_10")


#plt.plot(B0_1[:,0], -1*B0_1[:,col], 'r--',label="B0_1")
#plt.plot(B0_4[:,0], -1*B0_4[:,col], 'k--',label="B0_4")
#plt.plot(B0_7[:,0], -1*B0_7[:,col], 'g--',label="B0_7")
plt.plot(B2_10[:,0], -1*B2_10[:,col], 'b--',label="B2_10")



plt.legend()

plt.savefig('Nusselt.png')
